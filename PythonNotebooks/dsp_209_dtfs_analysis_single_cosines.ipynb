# %% [markdown]
# # Application 2.9. DTSF analysis of single cosines

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in [0, 1, 2, 16, 31]:
    x = np.arange(0, 32, 1)
    omega = i*2*np.pi/32
    y = 10 * np.cos( (1*omega) * x)

    plt.figure(figsize=(4, 1))
    plt.vlines(x, 0, y, colors='b', zorder=1)  # add vertical lines
    plt.axhline(0, color='black')  # add horizontal line at y=0
    plt.scatter(x, y, facecolors='none', edgecolors='b')  # add dots at the data points
    plt.xlabel("n")
    plt.ylabel(r'$x_0 [n]$')

    plt.show()
